# %% [markdown]
# # API validation
# Run the reusable validation pipeline. Output samples are saved in `data/raw/`.

# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(project_root))
script = project_root / 'scripts' / 'validate_apis.py'
# %run $script
